# %% [markdown]
# # relplot Tutorial

# %% [markdown]
# # 1.Import Libraries

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# # 2.Import Data

# %%
df = pd.read_csv('TRAIN (1).csv')
df.head()
# Out:
#          ID  Store_id Store_Type Location_Type Region_Code        Date  \
# 0  T1000001         1         S1            L3          R1  2018-01-01
# 1  T1000002       253         S4            L2          R1  2018-01-01
# 2  T1000003       252         S3            L2          R1  2018-01-01
# 3  T1000004       251         S2            L3          R1  2018-01-01
# 4  T1000005       250         S2            L3          R4  2018-01-01
#
#    Holiday Discount  #Order     Sales
# 0        1      Yes       9   7011.84
# 1        1      Yes      60  51789.12
# 2        1      Yes      42  36868.20
# 3        1      Yes      23  19715.16
# 4        1      Yes      62  45614.52

# %% [markdown]
# - relplot is used to plot relation plot between two variable. You can consider relplot as scatter plot.
# - While plotting relplot you have to give minimum values that is x,y, and data.

# %%
sns.relplot(x = '#Order',y = 'Sales',data = df)

# %% [markdown]
# - While Plotting relplot you can consider another feature as 'hue' and using 'hue' you can plot for particular feature.

# %%
sns.relplot(x = '#Order',y = 'Sales',hue = 'Location_Type',data = df)

# %% [markdown]
# - 'Style'used to change point font and even using style parameter you can consider another variable in graph and accordingly plotting will be changed.
# - In Below graph you can see, 'Hue' and 'style' consider as Location_type because of this data will plot accordingly. you can changed 'style' parameter and see how graph will plot.

# %%
sns.relplot(x = '#Order',y = 'Sales',hue = 'Location_Type',style = 'Location_Type',data = df)

# %% [markdown]
# - From above graph size of dots are same as all. you can plot these dots according to size of orders
# - Below graph is plotted accordingly size of orders.

# %%
sns.relplot(x = '#Order',y = 'Sales',size = '#Order',data = df)

# %% [markdown]
# - Sometimes graph dots will plot in small size.
# - To plot dots in large size you can increase size of dots by giving size to dots.

# %%
sns.relplot(x = '#Order',y = 'Sales',size = '#Order',sizes = (20,200),data = df)

# %% [markdown]
# # Line plot in relplot:-

# %% [markdown]
# - In relplot using feature called 'Kind' you can plot lineplot inside relplot.
# - To understand line plot you have to see below graph.

# %%
sns.relplot(x = '#Order',y = 'Sales',kind = 'line',data = df)

# %%
df.head()
# Out:
#          ID  Store_id Store_Type Location_Type Region_Code        Date  \
# 0  T1000001         1         S1            L3          R1  2018-01-01
# 1  T1000002       253         S4            L2          R1  2018-01-01
# 2  T1000003       252         S3            L2          R1  2018-01-01
# 3  T1000004       251         S2            L3          R1  2018-01-01
# 4  T1000005       250         S2            L3          R4  2018-01-01
#
#    Holiday Discount  #Order     Sales
# 0        1      Yes       9   7011.84
# 1        1      Yes      60  51789.12
# 2        1      Yes      42  36868.20
# 3        1      Yes      23  19715.16
# 4        1      Yes      62  45614.52

# %%
sns.relplot('Store_Type','Sales',data = df,kind = 'line')

# %%
sns.relplot('Store_Type','Sales',data = df,kind = 'line',ci = 'sd')
# Out:
# C:\Users\Kedar\conda\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.relplot('Store_Type','Sales',data = df,kind = 'line',ci = 'sd',estimator = None)
# Out:
# C:\Users\Kedar\conda\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.relplot('Store_Type','Sales',data = df,kind = 'line',ci = 'sd',estimator = sum)
# Out:
# C:\Users\Kedar\conda\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.relplot(x = 'Store_Type',y = 'Sales',hue = 'Location_Type',kind = 'line',data = df)

# %%
sns.relplot(x = 'Store_Type',y = 'Sales',hue = 'Location_Type',kind = 'line',data = df,style = 'Region_Code',ci = None)

# %%
sns.relplot(x = 'Store_Type',y = 'Sales',hue = 'Location_Type',kind = 'line',data = df,col = 'Region_Code',ci = None)

# %%
sns.relplot(x = 'Store_Type',y = 'Sales',hue = 'Location_Type',kind = 'line',data = df,col = 'Region_Code',col_wrap = 2,ci = None)
